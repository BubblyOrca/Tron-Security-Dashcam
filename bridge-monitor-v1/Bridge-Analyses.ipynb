# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bridge-volumes.csv")

# %%
df.head()
# Out:
#     Timestamp        Date    Multichain      Stargate  Polygon PoS Bridge  \
# 0  1661990400  01/09/2022  2.832459e+07  1.076479e+07        1.879982e+07
# 1  1662076800  02/09/2022  4.125046e+07  1.827752e+07        8.573213e+07
# 2  1662163200  03/09/2022  3.688005e+07  2.961998e+06        1.452552e+07
# 3  1662249600  04/09/2022  3.692814e+07  6.871145e+06        1.596684e+07
# 4  1662336000  05/09/2022  5.895961e+07  6.429510e+06        3.982750e+07
#
#    Avalanche Bridge  Portal by Wormhole   xDai Bridge  Arbitrum Bridge  \
# 0      4.767441e+07        2.452716e+06  6.834810e+05     8.030613e+07
# 1      2.148370e+07        1.728887e+06  7.474745e+05     5.194472e+06
# 2      1.099742e+07        7.544045e+05  1.326998e+05     6.320683e+06
# 3      2.293624e+06        2.772562e+06  1.462978e+06     8.649430e+06
# 4      6.616239e+06        1.590124e+06  1.386372e+06     1.138838e+07
#
#         Synapse  Optimism Gateway  Celer cBridge           Hop  Orbit Bridge  \
# 0  6.198534e+06      1.490493e+07   9.446788e+06  3.584919e+06  5.545721e+05
# 1  5.021249e+06      8.330424e+06   8.150957e+06  2.424903e+06  6.780806e+05
# 2  2.563153e+06      1.092038e+07   6.619460e+06  2.031486e+06  7.291925e+05
# 3  5.662454e+06      8.526934e+06   6.905700e+06  3.058052e+06  7.278487e+05
# 4  1.189686e+07      6.088945e+07   9.666435e+06  6.279780e+06  1.189363e+06
#
#          Across  Rainbow Bridge  Core Bitcoin Bridge     ChainPort  \
# 0  4.468532e+06    2.125543e+06         3.304743e+06  44961.933887
# 1  4.172379e+06    1.494714e+06         3.029069e+05  87227.780702
# 2  2.434479e+06    2.840317e+06         9.217630e+05  40343.840799
# 3  3.923991e+06    9.997904e+06         1.965486e+05  47666.055412
# 4  5.726280e+06    4.017736e+06         2.215408e+05  88084.961560
#
#          Optics         Total
# 0  44560.050442  2.336840e+08
# 1  17848.868341  2.050953e+08
# 2   8006.637373  1.016813e+08
# 3    113.269624  1.139919e+08
# 4   6769.487173  2.261800e+08

# %%
DeepnoteChart(df, """{"mark":{"type":"bar","tooltip":true},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{"x":{"sort":null,"type":"quantitative","field":"Avalanche Bridge","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"nominal","field":"Date","scale":{"type":"linear","zero":true}},"color":{"sort":null,"type":"nominal","field":"","scale":{"type":"linear","zero":false}}},"height":440,"width":"container","autosize":{"type":"fit"},"config":{"legend":{"labelFont":"Inter, sans-serif","labelFontSize":12,"titleFont":"Inter, sans-serif","titleFontSize":12,"titleFontWeight":"bold"},"title":{"anchor":"start","color":"#000000","font":"Inter, sans-serif","fontSize":22,"fontWeight":"normal"},"axis":{"labelFont":"Inter, sans-serif","labelFontSize":12,"labelFontWeight":"normal","titleFont":"Inter, sans-serif","titleFontSize":12,"titleFontWeight":"bold","labelOverlap":"greedy"}}}""")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=461f4382-f7c3-45e4-850f-327dc46c2c3d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
